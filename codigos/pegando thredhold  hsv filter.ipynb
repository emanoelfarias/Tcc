# %%
import cv2
import sys
import numpy as np

def nothing(x):
    pass

useCamera=False

# Check if filename is passed
if (True) :
    print "'Usage: python hsvThresholder.py <ImageFilePath>' to ignore camera and use a local image."
    useCamera = True

# Create a window
cv2.namedWindow('image')

# create trackbars for color change
cv2.createTrackbar('HMin','image',0,179,nothing) # Hue is from 0-179 for Opencv
cv2.createTrackbar('SMin','image',0,255,nothing)
cv2.createTrackbar('VMin','image',0,255,nothing)
cv2.createTrackbar('HMax','image',0,179,nothing)
cv2.createTrackbar('SMax','image',0,255,nothing)
cv2.createTrackbar('VMax','image',0,255,nothing)

# Set default value for MAX HSV trackbars.
cv2.setTrackbarPos('HMax', 'image', 179)
cv2.setTrackbarPos('SMax', 'image', 255)
cv2.setTrackbarPos('VMax', 'image', 255)

# Initialize to check if HSV min/max value changes
hMin = sMin = vMin = hMax = sMax = vMax = 0
phMin = psMin = pvMin = phMax = psMax = pvMax = 0

# Output Image to display
if useCamera:
    cap = cv2.VideoCapture(0)
    # Wait longer to prevent freeze for videos.
    waitTime = 330
else:
    img = cv2.imread(sys.argv[1])
    output = img
    waitTime = 33

while(1):

    if useCamera:
        # Capture frame-by-frame
        ret, img = cap.read()
        output = img
        print ret
    # get current positions of all trackbars
    hMin = cv2.getTrackbarPos('HMin','image')
    sMin = cv2.getTrackbarPos('SMin','image')
    vMin = cv2.getTrackbarPos('VMin','image')

    hMax = cv2.getTrackbarPos('HMax','image')
    sMax = cv2.getTrackbarPos('SMax','image')
    vMax = cv2.getTrackbarPos('VMax','image')

    # Set minimum and max HSV values to display
    lower = np.array([hMin, sMin, vMin])
    upper = np.array([hMax, sMax, vMax])

    # Create HSV Image and threshold into a range.
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    mask = cv2.inRange(hsv, lower, upper)
    output = cv2.bitwise_and(img,img, mask= mask)

    # Print if there is a change in HSV value
    if( (phMin != hMin) | (psMin != sMin) | (pvMin != vMin) | (phMax != hMax) | (psMax != sMax) | (pvMax != vMax) ):
        print("(hMin = %d , sMin = %d, vMin = %d), (hMax = %d , sMax = %d, vMax = %d)" % (hMin , sMin , vMin, hMax, sMax , vMax))
        phMin = hMin
        psMin = sMin
        pvMin = vMin
        phMax = hMax
        psMax = sMax
        pvMax = vMax

    # Display output image
    cv2.imshow('image',output)

    # Wait longer to prevent freeze for videos.
    if cv2.waitKey(waitTime) & 0xFF == ord('q'):
        break

# Release resources
if useCamera:
    cap.release()
cv2.destroyAllWindows()
# Out:
# 'Usage: python hsvThresholder.py <ImageFilePath>' to ignore camera and use a local image.
# True
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# (hMin = 15 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# True
# (hMin = 22 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# True
# (hMin = 3 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# True
# True
# True
# True
# (hMin = 0 , sMin = 4, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 36, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 37, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 78, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 93, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 96, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# True
# True
# (hMin = 0 , sMin = 60, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 37, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 35, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 139, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 158, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 157, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 146, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 135, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 134, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 129, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 121, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 114, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 93, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 95, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 99, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 100, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# True
# True
# True
# True
# (hMin = 0 , sMin = 100, vMin = 7), (hMax = 179 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 100, vMin = 56), (hMax = 179 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 100, vMin = 57), (hMax = 179 , sMax = 255, vMax = 255)
# True
# True
# (hMin = 0 , sMin = 100, vMin = 73), (hMax = 179 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 100, vMin = 115), (hMax = 179 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 100, vMin = 177), (hMax = 179 , sMax = 255, vMax = 255)
# True
# True
# True
# True
# (hMin = 0 , sMin = 100, vMin = 149), (hMax = 179 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 100, vMin = 139), (hMax = 179 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 100, vMin = 135), (hMax = 179 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 100, vMin = 134), (hMax = 179 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 100, vMin = 132), (hMax = 179 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 100, vMin = 127), (hMax = 179 , sMax = 255, vMax = 255)
# True
# True
# True
# True
# True
# True
# (hMin = 0 , sMin = 100, vMin = 127), (hMax = 134 , sMax = 255, vMax = 255)
# True
# True
# True
# (hMin = 0 , sMin = 100, vMin = 127), (hMax = 94 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 100, vMin = 127), (hMax = 62 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 100, vMin = 127), (hMax = 18 , sMax = 255, vMax = 255)
# True
# True
# True
# True
# (hMin = 0 , sMin = 100, vMin = 127), (hMax = 17 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 100, vMin = 127), (hMax = 0 , sMax = 255, vMax = 255)
# True
# True
# True
# True
# (hMin = 0 , sMin = 100, vMin = 127), (hMax = 16 , sMax = 255, vMax = 255)
# True
# True
# True
# True
# True
# True
# True
# (hMin = 0 , sMin = 100, vMin = 127), (hMax = 16 , sMax = 204, vMax = 255)
# True
# (hMin = 0 , sMin = 100, vMin = 127), (hMax = 16 , sMax = 153, vMax = 255)
# True
# True
# True
# True
# True
# True
# True
# True
# (hMin = 0 , sMin = 100, vMin = 127), (hMax = 16 , sMax = 176, vMax = 255)
# True
# (hMin = 0 , sMin = 100, vMin = 127), (hMax = 16 , sMax = 232, vMax = 255)
# True
# (hMin = 0 , sMin = 100, vMin = 127), (hMax = 16 , sMax = 255, vMax = 255)
# True
# True
# True
# True
# (hMin = 0 , sMin = 100, vMin = 127), (hMax = 16 , sMax = 255, vMax = 202)
# True
# True
# (hMin = 0 , sMin = 100, vMin = 127), (hMax = 16 , sMax = 255, vMax = 198)
# True
# (hMin = 0 , sMin = 100, vMin = 127), (hMax = 16 , sMax = 255, vMax = 95)
# True
# (hMin = 0 , sMin = 100, vMin = 127), (hMax = 16 , sMax = 255, vMax = 52)
# True
# (hMin = 0 , sMin = 100, vMin = 127), (hMax = 16 , sMax = 255, vMax = 99)
# True
# (hMin = 0 , sMin = 100, vMin = 127), (hMax = 16 , sMax = 255, vMax = 106)
# True
# (hMin = 0 , sMin = 100, vMin = 127), (hMax = 16 , sMax = 255, vMax = 115)
# True
# (hMin = 0 , sMin = 100, vMin = 127), (hMax = 16 , sMax = 255, vMax = 128)
# True
# (hMin = 0 , sMin = 100, vMin = 127), (hMax = 16 , sMax = 255, vMax = 137)
# True
# (hMin = 0 , sMin = 100, vMin = 127), (hMax = 16 , sMax = 255, vMax = 139)
# True
# (hMin = 0 , sMin = 100, vMin = 127), (hMax = 16 , sMax = 255, vMax = 144)
# True
# (hMin = 0 , sMin = 100, vMin = 127), (hMax = 16 , sMax = 255, vMax = 147)
# True
# True
# (hMin = 0 , sMin = 100, vMin = 127), (hMax = 16 , sMax = 255, vMax = 148)
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# (hMin = 0 , sMin = 100, vMin = 127), (hMax = 16 , sMax = 255, vMax = 180)
# True
# (hMin = 0 , sMin = 100, vMin = 127), (hMax = 16 , sMax = 255, vMax = 255)
# True
# True
# True
# True
# True
# (hMin = 0 , sMin = 100, vMin = 127), (hMax = 19 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 100, vMin = 127), (hMax = 79 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 100, vMin = 127), (hMax = 85 , sMax = 255, vMax = 255)
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# (hMin = 0 , sMin = 139, vMin = 127), (hMax = 85 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 155, vMin = 127), (hMax = 85 , sMax = 255, vMax = 255)
# True
# True
# (hMin = 0 , sMin = 144, vMin = 127), (hMax = 85 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 143, vMin = 127), (hMax = 85 , sMax = 255, vMax = 255)
# True
# True
# (hMin = 0 , sMin = 157, vMin = 127), (hMax = 85 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 159, vMin = 127), (hMax = 85 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 160, vMin = 127), (hMax = 85 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 159, vMin = 127), (hMax = 85 , sMax = 255, vMax = 255)
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# (hMin = 0 , sMin = 129, vMin = 127), (hMax = 85 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 126, vMin = 127), (hMax = 85 , sMax = 255, vMax = 255)
# True
# True
# True
# True
# True
# True
# True
# (hMin = 33 , sMin = 126, vMin = 127), (hMax = 85 , sMax = 255, vMax = 255)
# True
# True
# True
# (hMin = 26 , sMin = 126, vMin = 127), (hMax = 85 , sMax = 255, vMax = 255)
# True
# (hMin = 21 , sMin = 126, vMin = 127), (hMax = 85 , sMax = 255, vMax = 255)
# True
# (hMin = 20 , sMin = 126, vMin = 127), (hMax = 85 , sMax = 255, vMax = 255)
# True
# (hMin = 16 , sMin = 126, vMin = 127), (hMax = 85 , sMax = 255, vMax = 255)
# True
# (hMin = 14 , sMin = 126, vMin = 127), (hMax = 85 , sMax = 255, vMax = 255)
# True
# (hMin = 11 , sMin = 126, vMin = 127), (hMax = 85 , sMax = 255, vMax = 255)
# True
# (hMin = 8 , sMin = 126, vMin = 127), (hMax = 85 , sMax = 255, vMax = 255)
# True
# (hMin = 5 , sMin = 126, vMin = 127), (hMax = 85 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 126, vMin = 127), (hMax = 85 , sMax = 255, vMax = 255)
# True
# True
# True
# True
# True
# True
# True
# (hMin = 0 , sMin = 126, vMin = 127), (hMax = 90 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 126, vMin = 127), (hMax = 92 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 126, vMin = 127), (hMax = 93 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 126, vMin = 127), (hMax = 97 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 126, vMin = 127), (hMax = 103 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 126, vMin = 127), (hMax = 105 , sMax = 255, vMax = 255)
# True
# True
# (hMin = 0 , sMin = 126, vMin = 127), (hMax = 115 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 126, vMin = 127), (hMax = 116 , sMax = 255, vMax = 255)
# True
# True
# True
# True
# True
# True
# (hMin = 0 , sMin = 126, vMin = 127), (hMax = 129 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 126, vMin = 127), (hMax = 130 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 126, vMin = 127), (hMax = 131 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 126, vMin = 127), (hMax = 132 , sMax = 255, vMax = 255)
# True
# True
# (hMin = 0 , sMin = 126, vMin = 127), (hMax = 130 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 126, vMin = 127), (hMax = 126 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 126, vMin = 127), (hMax = 129 , sMax = 255, vMax = 255)
# True
# True
# (hMin = 0 , sMin = 126, vMin = 127), (hMax = 131 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 126, vMin = 127), (hMax = 136 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 126, vMin = 127), (hMax = 150 , sMax = 255, vMax = 255)
# True
# True
# (hMin = 0 , sMin = 126, vMin = 127), (hMax = 134 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 126, vMin = 127), (hMax = 111 , sMax = 255, vMax = 255)
# True
# True
# True
# True
# True
# True
# True
# (hMin = 0 , sMin = 126, vMin = 127), (hMax = 110 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 126, vMin = 127), (hMax = 99 , sMax = 255, vMax = 255)
# True
# True
# True
# (hMin = 0 , sMin = 126, vMin = 127), (hMax = 93 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 126, vMin = 127), (hMax = 91 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 126, vMin = 127), (hMax = 88 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 126, vMin = 127), (hMax = 87 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 126, vMin = 127), (hMax = 91 , sMax = 255, vMax = 255)
# True
# True
# (hMin = 0 , sMin = 126, vMin = 127), (hMax = 116 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 126, vMin = 127), (hMax = 127 , sMax = 255, vMax = 255)
# True
# True
# True
# True
# (hMin = 0 , sMin = 126, vMin = 127), (hMax = 127 , sMax = 204, vMax = 255)
# True
# True
# (hMin = 0 , sMin = 126, vMin = 127), (hMax = 127 , sMax = 153, vMax = 255)
# True
# True
# True
# True
# True
# (hMin = 0 , sMin = 126, vMin = 127), (hMax = 127 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 126, vMin = 127), (hMax = 127 , sMax = 204, vMax = 255)
# True
# True
# True
# True
# (hMin = 0 , sMin = 126, vMin = 127), (hMax = 127 , sMax = 234, vMax = 255)
# True
# (hMin = 0 , sMin = 126, vMin = 127), (hMax = 127 , sMax = 255, vMax = 255)
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# (hMin = 24 , sMin = 126, vMin = 127), (hMax = 127 , sMax = 255, vMax = 255)
# True
# True
# (hMin = 13 , sMin = 126, vMin = 127), (hMax = 127 , sMax = 255, vMax = 255)
# True
# (hMin = 11 , sMin = 126, vMin = 127), (hMax = 127 , sMax = 255, vMax = 255)
# True
# (hMin = 6 , sMin = 126, vMin = 127), (hMax = 127 , sMax = 255, vMax = 255)
# True
# (hMin = 1 , sMin = 126, vMin = 127), (hMax = 127 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 126, vMin = 127), (hMax = 127 , sMax = 255, vMax = 255)
# True
# True
# True
# True
# True
# True
# (hMin = 0 , sMin = 111, vMin = 127), (hMax = 127 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 84, vMin = 127), (hMax = 127 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 81, vMin = 127), (hMax = 127 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 83, vMin = 127), (hMax = 127 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 90, vMin = 127), (hMax = 127 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 95, vMin = 127), (hMax = 127 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 96, vMin = 127), (hMax = 127 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 99, vMin = 127), (hMax = 127 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 107, vMin = 127), (hMax = 127 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 111, vMin = 127), (hMax = 127 , sMax = 255, vMax = 255)
# True
# True
# (hMin = 0 , sMin = 125, vMin = 127), (hMax = 127 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 126, vMin = 127), (hMax = 127 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 114, vMin = 127), (hMax = 127 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 107, vMin = 127), (hMax = 127 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 108, vMin = 127), (hMax = 127 , sMax = 255, vMax = 255)
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# (hMin = 0 , sMin = 108, vMin = 137), (hMax = 127 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 108, vMin = 151), (hMax = 127 , sMax = 255, vMax = 255)
# True
# True
# (hMin = 0 , sMin = 108, vMin = 148), (hMax = 127 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 108, vMin = 126), (hMax = 127 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 108, vMin = 97), (hMax = 127 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 108, vMin = 92), (hMax = 127 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 108, vMin = 109), (hMax = 127 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 108, vMin = 118), (hMax = 127 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 108, vMin = 120), (hMax = 127 , sMax = 255, vMax = 255)
# True
# True
# (hMin = 0 , sMin = 108, vMin = 123), (hMax = 127 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 108, vMin = 126), (hMax = 127 , sMax = 255, vMax = 255)
# True
# True
# True
# True
# True
# True
# (hMin = 0 , sMin = 108, vMin = 126), (hMax = 150 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 108, vMin = 126), (hMax = 156 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 108, vMin = 126), (hMax = 161 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 108, vMin = 126), (hMax = 179 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 108, vMin = 126), (hMax = 172 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 108, vMin = 126), (hMax = 128 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 108, vMin = 126), (hMax = 117 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 108, vMin = 126), (hMax = 107 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 108, vMin = 126), (hMax = 99 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 108, vMin = 126), (hMax = 88 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 108, vMin = 126), (hMax = 81 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 108, vMin = 126), (hMax = 67 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 108, vMin = 126), (hMax = 61 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 108, vMin = 126), (hMax = 33 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 108, vMin = 126), (hMax = 24 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 108, vMin = 126), (hMax = 21 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 108, vMin = 126), (hMax = 20 , sMax = 255, vMax = 255)
# True
# True
# True
# True
# True
# True
# True
# True
# (hMin = 0 , sMin = 108, vMin = 126), (hMax = 0 , sMax = 255, vMax = 255)
# True
# True
# (hMin = 0 , sMin = 108, vMin = 126), (hMax = 6 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 108, vMin = 126), (hMax = 7 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 108, vMin = 126), (hMax = 4 , sMax = 255, vMax = 255)
# True
# True
# True
# True
# (hMin = 0 , sMin = 108, vMin = 126), (hMax = 6 , sMax = 255, vMax = 255)
# True
# (hMin = 0 , sMin = 108, vMin = 126), (hMax = 8 , sMax = 255, vMax = 255)
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-87dcdb09b048> in <module>()
#      82
#      83     # Wait longer to prevent freeze for videos.
# ---> 84     if cv2.waitKey(waitTime) & 0xFF == ord('q'):
#      85         break
#      86
#
# KeyboardInterrupt:
